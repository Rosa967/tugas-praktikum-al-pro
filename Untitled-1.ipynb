# %%
#membuat nama toko
nama_makanan = input('masukan nama makanan:' )
nama_karakter = input('masukan nama karakter:')
nama_sifat = input('masukan nama sifat:')
print("nama toko adalah", nama_makanan, nama_karakter, nama_sifat)
# Out:
# nama toko adalah ayam oca imut

# %%
#menghitung modal awal
modal_doraemon = 555000
modal_nobita = 333000
modal_shizuka = 222000
total_modal = modal_doraemon + modal_nobita + modal_shizuka
print('total modal adalah', total_modal)
# Out:
# total modal adalah 1110000

# %%
#menghitung pendapatan bulan ini
jumlah_dorayaki = 350
jumlah_harga = 5000
total_pendapatan = jumlah_dorayaki * jumlah_harga
print('total pendapatan adalah',total_pendapatan )
# Out:
# total pendapatan adalah 1750000

# %%
#menghitung total keuntungan
jumlah_pendapatan = 1750000
jumlah_modal = 1110000
total_keuntungan = jumlah_pendapatan - jumlah_modal
print('total keuntungan adalah',total_keuntungan)
# Out:
# total keuntungan adalah 640000
